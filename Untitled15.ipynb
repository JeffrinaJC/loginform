# %% [markdown]
# <a href="https://colab.research.google.com/github/JeffrinaJC/loginform/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("anandkumarsahu09/cattle-breeds-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'cattle-breeds-dataset' dataset.
# Path to dataset files: /kaggle/input/cattle-breeds-dataset

# %%
import os
import shutil
import random

# Path to your dataset
dataset_dir = "/kaggle/input/cattle-breeds-dataset/Cattle Breeds"

# Where you want the new split dataset
output_dir = "cattle_breeds_split"

# Train/val ratio
val_split = 0.2

# Allowed image extensions
img_exts = [".jpg", ".jpeg", ".png", ".bmp"]

# Loop through each breed folder
for breed in os.listdir(dataset_dir):
    breed_path = os.path.join(dataset_dir, breed)

    if not os.path.isdir(breed_path):
        continue  # skip if not a folder

    # Get only image files
    images = [f for f in os.listdir(breed_path)
              if os.path.isfile(os.path.join(breed_path, f)) and os.path.splitext(f)[1].lower() in img_exts]

    random.shuffle(images)

    # Split index
    split_idx = int(len(images) * (1 - val_split))
    train_images = images[:split_idx]
    val_images = images[split_idx:]

    # Make new folders
    train_dir = os.path.join(output_dir, "train", breed)
    val_dir = os.path.join(output_dir, "val", breed)
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)

    # Copy images
    for img in train_images:
        shutil.copy(os.path.join(breed_path, img), os.path.join(train_dir, img))
    for img in val_images:
        shutil.copy(os.path.join(breed_path, img), os.path.join(val_dir, img))

print("✅ Dataset split into train/val folders successfully!")
# Out:
# ✅ Dataset split into train/val folders successfully!

# %%
training_data = "/content/cattle_breeds_split/train"

# %%
validation_data = "/content/cattle_breeds_split/val"

# %%
import os

print(os.listdir(training_data))
# Out:
# ['Jersey cattle', 'Ayrshire cattle', 'Brown Swiss cattle', 'Holstein Friesian cattle', 'Red Dane cattle']

# %%
import cv2
import matplotlib.pyplot as plt
import os

# Training data denoising

training_data = "cattle_breeds_split/train"
output_train_denoised = "preprocess/train"
target_size = (224, 224)  # Resize for MobileNet

os.makedirs(output_train_denoised, exist_ok=True)

for breed in os.listdir(training_data):
    breed_path = os.path.join(training_data, breed)
    output_breed_path = os.path.join(output_train_denoised, breed)  # ✅ corrected path
    os.makedirs(output_breed_path, exist_ok=True)

    for img_file in os.listdir(breed_path):
        img_path = os.path.join(breed_path, img_file)
        output_path = os.path.join(output_breed_path, img_file)  # ✅ corrected path

        # Load and preprocess image
        img = cv2.imread(img_path)
        if img is None:
            continue

        # Denoising step
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        denoised = cv2.fastNlMeansDenoisingColored(
            img, None, h=10, hColor=10, templateWindowSize=7, searchWindowSize=21
        )
        resized = cv2.resize(denoised, target_size)

        # Convert back to BGR for saving
        final_img = cv2.cvtColor(resized, cv2.COLOR_RGB2BGR)
        cv2.imwrite(output_path, final_img)

print("✅ Denoising and preprocessing complete for all training images.")
# Out:
# ✅ Denoising and preprocessing complete for all training images.

# %%
import cv2
import matplotlib.pyplot as plt
import os

# Training data denoising

validation_data = "cattle_breeds_split/val"
output_val_denoised = "preprocess/val"
target_size = (224, 224)  # Resize for MobileNet

os.makedirs(output_train_denoised, exist_ok=True)

for breed in os.listdir(validation_data):
    breed_path = os.path.join(validation_data, breed)
    output_breed_path = os.path.join(output_val_denoised, breed)
    os.makedirs(output_breed_path, exist_ok=True)

    for img_file in os.listdir(breed_path):
        img_path = os.path.join(breed_path, img_file)
        output_path = os.path.join(output_breed_path, img_file)

        # Load and preprocess image
        img = cv2.imread(img_path)
        if img is None:
            continue

        # Denoising step
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        denoised = cv2.fastNlMeansDenoisingColored(
            img, None, h=10, hColor=10, templateWindowSize=7, searchWindowSize=21
        )
        resized = cv2.resize(denoised, target_size)

        # Convert back to BGR for saving
        final_img = cv2.cvtColor(resized, cv2.COLOR_RGB2BGR)
        cv2.imwrite(output_path, final_img)

print("✅ Denoising and preprocessing complete for all validation images.")
# Out:
# ✅ Denoising and preprocessing complete for all validation images.

# %%
import cv2
import matplotlib.pyplot as plt
import os
import random

# Path to original and denoised folders
original_root = "cattle_breeds_split/train"
denoised_root = "preprocess/train"

# Pick a random breed folder
breed_folder = random.choice(os.listdir(original_root))
original_breed_path = os.path.join(original_root, breed_folder)
denoised_breed_path = os.path.join(denoised_root, breed_folder)

# Pick a random image file
img_file = random.choice(os.listdir(original_breed_path))
original_img_path = os.path.join(original_breed_path, img_file)
denoised_img_path = os.path.join(denoised_breed_path, img_file)

# Load both images
original_img = cv2.imread(original_img_path)
denoised_img = cv2.imread(denoised_img_path)

# Convert BGR to RGB for display
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
denoised_img = cv2.cvtColor(denoised_img, cv2.COLOR_BGR2RGB)

# Plot side by side
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(original_img)
plt.axis("off")
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(denoised_img)
plt.axis("off")
plt.title("Denoised Image")

plt.suptitle(f"Breed: {breed_folder}", fontsize=14)
plt.show()

# %%
import tensorflow as tf

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "preprocess/train",
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "preprocess/val",
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 965 files belonging to 5 classes.
# Found 243 files belonging to 5 classes.

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False  # Freeze base

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(len(train_ds.class_names), activation='softmax')
])
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(train_ds, validation_data=val_ds, epochs=10)
# Out:
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.2329 - loss: 1.8671 - val_accuracy: 0.3374 - val_loss: 1.4560
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.4483 - loss: 1.3747 - val_accuracy: 0.4650 - val_loss: 1.3763
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.4840 - loss: 1.2589 - val_accuracy: 0.4321 - val_loss: 1.3976
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.5007 - loss: 1.2208 - val_accuracy: 0.4691 - val_loss: 1.2883
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5757 - loss: 1.1010 - val_accuracy: 0.4156 - val_loss: 1.3215
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.5942 - loss: 1.0775 - val_accuracy: 0.4239 - val_loss: 1.2921
# Epoch 7/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5957 - loss: 1.0455 - val_accuracy: 0.4856 - val_loss: 1.2707
# Epoch 8/10
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2]
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_ds = train_datagen.flow_from_directory(
    "preprocess/train",
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse'
)

val_ds = val_datagen.flow_from_directory(
    "preprocess/val",
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse'
)
# Out:
# Found 965 images belonging to 5 classes.
# Found 243 images belonging to 5 classes.

# %%
model.save("cattle_breed_classifier.h5")
print("✅ Model saved successfully.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model saved successfully.

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title("Training vs Validation Accuracy")
plt.show()

# %%
from tensorflow.keras.models import load_model

model = load_model("cattle_breed_classifier.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import cv2
import numpy as np

img_path = "/content/cattle_breeds_split/train/Ayrshire cattle/Ayrshirecattle0.jpg"  # Replace with your image path
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (224, 224))
img = img / 255.0  # Normalize
img = np.expand_dims(img, axis=0)  # Add batch dimension

# %%
pred = model.predict(img)
predicted_class = np.argmax(pred)
confidence = np.max(pred)

print("Predicted class index:", predicted_class)
print("Confidence:", round(confidence * 100, 2), "%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted class index: 1
# Confidence: 77.94 %

# %%
class_names = list(train_ds.class_indices.keys())
print("Predicted breed:", class_names[predicted_class])
# Out:
# Predicted breed: Brown Swiss cattle

# %%
import os

train_dir = "preprocess/train"
for breed in os.listdir(train_dir):
    count = len(os.listdir(os.path.join(train_dir, breed)))
    print(f"{breed}: {count} images")
# Out:
# Jersey cattle: 201 images
# Ayrshire cattle: 208 images
# Brown Swiss cattle: 190 images
# Holstein Friesian cattle: 203 images
# Red Dane cattle: 163 images

# %%
import os

train_dir = "preprocess/train"
for breed in os.listdir(train_dir):
    count = len(os.listdir(os.path.join(train_dir, breed)))
    print(f"{breed}: {count} images")
# Out:
# Jersey cattle: 201 images
# Ayrshire cattle: 208 images
# Brown Swiss cattle: 190 images
# Holstein Friesian cattle: 203 images
# Red Dane cattle: 163 images

# %%
base_model.trainable = True  # Unfreeze the base
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_ds, validation_data=val_ds, epochs=5)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.2019 - loss: 4.1423 - val_accuracy: 0.2016 - val_loss: 4.0520
# Epoch 2/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.1907 - loss: 3.9737 - val_accuracy: 0.2099 - val_loss: 3.8666
# Epoch 3/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.2111 - loss: 3.6952 - val_accuracy: 0.2263 - val_loss: 3.6902
# Epoch 4/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.2310 - loss: 3.6163 - val_accuracy: 0.2181 - val_loss: 3.5244
# Epoch 5/5
# ...

# %%
from tensorflow.keras import layers

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.15),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomBrightness(0.2)
])

# %%
c
# Out:
# Jersey cattle: 201 images
# Ayrshire cattle: 208 images
# Brown Swiss cattle: 190 images
# Holstein Friesian cattle: 203 images
# Red Dane cattle: 163 images

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "preprocess/train",
    image_size=(224, 224),
    batch_size=32
)

num_classes = len(train_ds.class_names)
# Out:
# Found 965 files belonging to 5 classes.

# %%
import os

train_dir = "preprocess/train"
for breed in sorted(os.listdir(train_dir)):
    count = len(os.listdir(os.path.join(train_dir, breed)))
    print(f"{breed}: {count} images")
# Out:
# Ayrshire cattle: 208 images
# Brown Swiss cattle: 190 images
# Holstein Friesian cattle: 203 images
# Jersey cattle: 201 images
# Red Dane cattle: 163 images

# %%
class_names = sorted(os.listdir("preprocess/train"))  # Must match training order

# %%
base_model.trainable = True
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_ds, validation_data=val_ds, epochs=10)
# Out:
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.6587 - loss: 0.9530 - val_accuracy: 0.1975 - val_loss: 4.2692
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.6953 - loss: 0.9263 - val_accuracy: 0.1975 - val_loss: 4.2839
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.6796 - loss: 0.9357 - val_accuracy: 0.1975 - val_loss: 4.3066
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.6908 - loss: 0.9161 - val_accuracy: 0.1934 - val_loss: 4.3166
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.7081 - loss: 0.9226 - val_accuracy: 0.1934 - val_loss: 4.3251
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.6751 - loss: 0.9444 - val_accuracy: 0.1934 - val_loss: 4.3215
# Epoch 7/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.6873 - loss: 0.9215 - val_accuracy: 0.1934 - val_loss: 4.3217
# Epoch 8/10
# ...

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.15),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomBrightness(0.2)
])

# %%
print("Raw prediction vector:", pred)
# Out:
# Raw prediction vector: [[0.12416893 0.79115725 0.01695994 0.0167091  0.05100474]]

# %%
from tensorflow.keras import layers, models
model = models.Sequential([
    data_augmentation,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

y_pred = np.argmax(model.predict(val_ds), axis=1)
y_true = np.concatenate([y for x, y in val_ds], axis=0)

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step

# %%
base_model.trainable = True  # Unfreeze the base

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),  # Low learning rate
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(train_ds, validation_data=val_ds, epochs=10)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-694216484.py in <cell line: 0>()
#       7 )
#       8
# ----> 9 model.fit(train_ds, validation_data=val_ds, epochs=10)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
# ...

# %%
history = model.fit(train_ds, validation_data=val_ds, epochs=10)

# Plot training and validation accuracy
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Model Accuracy Over Epochs')
plt.show()
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1476683279.py in <cell line: 0>()
# ----> 1 history = model.fit(train_ds, validation_data=val_ds, epochs=10)
#       2
#       3 # Plot training and validation accuracy
#       4 import matplotlib.pyplot as plt
#       5
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in multi_step_on_iterator(iterator)
#     130         def multi_step_on_iterator(iterator):
# ...

# %%
loss, accuracy = model.evaluate(val_ds)
print("✅ Validation Accuracy:", round(accuracy * 100, 2), "%")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2219 - loss: 1.7702
# ✅ Validation Accuracy: 19.75 %

# %%
# Count images per class
import os
def count_images(root):
    classes = []
    counts = []
    for c in sorted(os.listdir(root)):
        p = os.path.join(root, c)
        if os.path.isdir(p):
            cnt = len([f for f in os.listdir(p) if os.path.splitext(f)[1].lower() in [".jpg",".jpeg",".png",".bmp"]])
            classes.append(c)
            counts.append(cnt)
    return classes, counts

train_classes, train_counts = count_images(training_data)
val_classes, val_counts = count_images(validation_data)

print("Train classes (count):")
for c, cnt in zip(train_classes, train_counts):
    print(f"  {c}: {cnt}")

print("\nVal classes (count):")
for c, cnt in zip(val_classes, val_counts):
    print(f"  {c}: {cnt}")

# Check for mismatch in class lists
if sorted(train_classes) != sorted(val_classes):
    print("\nWARNING: Train and val class lists differ. Make sure folder names match exactly.")
# Out:
# Train classes (count):
#   Ayrshire cattle: 208
#   Brown Swiss cattle: 190
#   Holstein Friesian cattle: 203
#   Jersey cattle: 201
#   Red Dane cattle: 163
#
# Val classes (count):
#   Ayrshire cattle: 52
#   Brown Swiss cattle: 48
#   Holstein Friesian cattle: 51
#   Jersey cattle: 51
#   Red Dane cattle: 41

# %%
import cv2

def remove_corrupt(root):
    removed = 0
    for c in os.listdir(root):
        p = os.path.join(root, c)
        if not os.path.isdir(p): continue
        for fname in os.listdir(p):
            fpath = os.path.join(p, fname)
            try:
                img = cv2.imread(fpath)
                if img is None:
                    os.remove(fpath)
                    removed += 1
            except Exception:
                os.remove(fpath)
                removed += 1
    return removed

print("Removed corrupt train images:", remove_corrupt(training_data))
print("Removed corrupt val images:", remove_corrupt(validation_data))
# Out:
# Removed corrupt train images: 0
# Removed corrupt val images: 0

# %%
# 0) Imports & config
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

AUTOTUNE = tf.data.AUTOTUNE
BATCH_SIZE = 32
IMG_SIZE = (224, 224)

#

# 2) Quick sanity: make sure directories exist
for p in [training_data, validation_data]:
    if not os.path.exists(p):
        raise FileNotFoundError(f"Path not found: {p} - update TRAIN_DIR/VAL_DIR")

# 3) Create raw datasets (so we can extract class names)
raw_train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='int',
    shuffle=True
)
raw_val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    VAL_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='int',
    shuffle=False
)

# 4) Save class names and show mapping
class_names = raw_train_ds.class_names
num_classes = len(class_names)
print("Found classes (index -> name):")
for idx, name in enumerate(class_names):
    print(f"  {idx} -> {name}")
print(f"Total classes: {num_classes}")

# 5) Compute per-class image counts and class-weights (simple inverse-frequency)
train_counts = {c: len([f for f in os.listdir(os.path.join(TRAIN_DIR, c))
                        if os.path.splitext(f)[1].lower() in [".jpg",".jpeg",".png",".bmp"]])
                for c in class_names}
print("\nTrain counts per class:")
for c in class_names:
    print(f"  {c}: {train_counts[c]} images")

counts_arr = np.array([train_counts[c] for c in class_names])
total = counts_arr.sum()
class_weights = {i: total / (num_classes * counts_arr[i]) for i in range(num_classes)}
print("\nClass weights (used during training):")
print(class_weights)

# 6) Build augmentation (Keras layers) and preprocessing pipeline
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.12),
    layers.RandomZoom(0.15),
    layers.RandomTranslation(0.08, 0.08),
    layers.RandomContrast(0.12),
], name="data_augmentation")

# 7) Apply MobileNet preprocess_input and augmentation for train only
train_ds = raw_train_ds.map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)

val_ds = raw_val_ds.map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# 8) Build the model (MobileNetV2 base + classifier head)
base_model = MobileNetV2(input_shape=IMG_SIZE + (3,), include_top=False, weights="imagenet")
base_model.trainable = False  # freeze for initial training

inputs = layers.Input(shape=IMG_SIZE + (3,))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)
model = models.Model(inputs, outputs)

model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

# 9) Callbacks
checkpoint = ModelCheckpoint("best_model.h5", monitor='val_accuracy', save_best_only=True, verbose=1)
es = EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7, verbose=1)

# 10) Train top layers
initial_epochs = 12
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=initial_epochs,
    class_weight=class_weights,
    callbacks=[checkpoint, es, rlr]
)

# 11) Plot training curves
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(); plt.title("Loss")

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend(); plt.title("Accuracy")
plt.show()

# 12) Fine-tune: unfreeze last part of the base model and train with low LR
base_model.trainable = True
# Freeze earlier layers, unfreeze last N layers to fine-tune
UNFREEZE_FROM = int(len(base_model.layers) * 0.7)  # try unfreezing last 30%
for i, layer in enumerate(base_model.layers):
    layer.trainable = True if i >= UNFREEZE_FROM else False

model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

fine_epochs = 15
history_fine = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=fine_epochs,
    class_weight=class_weights,
    callbacks=[checkpoint, es, rlr]
)

# 13) Load best and evaluate on validation set
model = tf.keras.models.load_model("best_model.h5")
val_loss, val_acc = model.evaluate(val_ds)
print(f"\n✅ Validation accuracy: {val_acc*100:.2f}%")

# 14) Confusion matrix & classification report
# Build y_true and y_pred arrays
y_true = np.concatenate([y.numpy() for x, y in val_ds], axis=0)
y_prob = model.predict(val_ds)
y_pred = np.argmax(y_prob, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
plt.xlabel("Predicted"); plt.ylabel("True"); plt.title("Confusion Matrix (val)")
plt.show()

print("\nClassification report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# 15) Quick Grad-CAM utility (inspect one validation image)
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        last_conv_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]
    grads = tape.gradient(class_channel, last_conv_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    last_conv_output = last_conv_output[0]
    heatmap = last_conv_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / (tf.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy()

# Find last conv layer name inside base_model
# Out:
# Found 965 files belonging to 5 classes.
# Found 243 files belonging to 5 classes.
# Found classes (index -> name):
#   0 -> Ayrshire cattle
#   1 -> Brown Swiss cattle
#   2 -> Holstein Friesian cattle
#   3 -> Jersey cattle
#   4 -> Red Dane cattle
# Total classes: 5
#
# Train counts per class:
#   Ayrshire cattle: 208 images
#   Brown Swiss cattle: 190 images
#   Holstein Friesian cattle: 203 images
#   Jersey cattle: 201 images
#   Red Dane cattle: 163 images
#
# Class weights (used during training):
# {0: np.float64(0.9278846153846154), 1: np.float64(1.0157894736842106), 2: np.float64(0.9507389162561576), 3: np.float64(0.9601990049751243), 4: np.float64(1.1840490797546013)}
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# ...

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name):
    # Fetch the last conv layer from inside base_model
    last_conv_layer = model.layers[0].get_layer(last_conv_layer_name)

    # Build a grad_model that takes the full model input
    grad_model = tf.keras.models.Model(
        [model.input],
        [last_conv_layer.output, model.output]
    )

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        class_idx = tf.argmax(predictions[0])
        loss = predictions[:, class_idx]

    # Gradient of class output wrt conv layer output
    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # Normalize heatmap
    heatmap = tf.maximum(heatmap, 0) / (tf.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy()

# %%
# ✅ Find last conv layer inside MobileNetV2 (which is at index 1 in model.layers)
last_conv_name = None
for layer in reversed(model.layers[1].layers):  # index 1 = base_model
    if isinstance(layer, tf.keras.layers.Conv2D):
        last_conv_name = layer.name
        break

print("Last conv layer:", last_conv_name)
# Out:
# Last conv layer: Conv_1

# %%
heatmap = make_gradcam_heatmap(sample_img, model, last_conv_name)

plt.matshow(heatmap)
plt.title("Grad-CAM heatmap")
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3881797448.py in <cell line: 0>()
# ----> 1 heatmap = make_gradcam_heatmap(sample_img, model, last_conv_name)
#       2
#       3 plt.matshow(heatmap)
#       4 plt.title("Grad-CAM heatmap")
#       5 plt.colorbar()
#
# /tmp/ipython-input-2343410795.py in make_gradcam_heatmap(img_array, model, last_conv_layer_name)
#       1 def make_gradcam_heatmap(img_array, model, last_conv_layer_name):
#       2     # Fetch the last conv layer from inside base_model
# ----> 3     last_conv_layer = model.layers[0].get_layer(last_conv_layer_name)
#       4
#       5     # Build a grad_model that takes the full model input
#
# AttributeError: 'InputLayer' object has no attribute 'get_layer'
